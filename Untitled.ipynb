# %%
import skfda
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20352/1337897178.py in <module>
# ----> 1 import skfda
#
# ~\miniconda3\envs\analisiecg37\lib\site-packages\skfda\__init__.py in <module>
#      30 import errno as _errno
#      31
# ---> 32 from .representation import FData
#      33 from .representation import FDataBasis
#      34 from .representation import FDataGrid
#
# ~\miniconda3\envs\analisiecg37\lib\site-packages\skfda\representation\__init__.py in <module>
# ----> 1 from . import basis
#       2 from . import extrapolation
#       3 from . import grid
#       4 from . import interpolation
#       5 from ._evaluation_trasformer import EvaluationTransformer
#
# ~\miniconda3\envs\analisiecg37\lib\site-packages\skfda\representation\basis\__init__.py in <module>
# ----> 1 from ._basis import Basis
#       2 from ._bspline import BSpline
# ...
